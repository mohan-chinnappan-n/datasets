# %%
# !pip install pandas

# %% [markdown]
# import pandas as pd

# %% [markdown]
# ### Refer
# - [Plotting in Pandas](https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html)

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/mohan-chinnappan-n/datasets/master/cars/cars3.csv')

# %%
df1.head()
# Out:
#    id Manufacturer    Model Vehicle_type  Sales_in_thousands
# 0   0        Acura  Integra    Passenger              16.919
# 1   1        Acura       TL    Passenger              39.384
# 2   2        Acura       CL    Passenger              14.114
# 3   3        Acura       RL    Passenger               8.588
# 4   4         Audi       A4    Passenger              20.397

# %%
df1
# Out:
#       id Manufacturer    Model Vehicle_type  Sales_in_thousands
# 0      0        Acura  Integra    Passenger              16.919
# 1      1        Acura       TL    Passenger              39.384
# 2      2        Acura       CL    Passenger              14.114
# 3      3        Acura       RL    Passenger               8.588
# 4      4         Audi       A4    Passenger              20.397
# ..   ...          ...      ...          ...                 ...
# 152  152        Volvo      V40    Passenger               3.545
# 153  153        Volvo      S70    Passenger              15.245
# 154  154        Volvo      V70    Passenger              17.531
# 155  155        Volvo      C70    Passenger               3.493
# 156  156        Volvo      S80    Passenger              18.969
#
# [157 rows x 5 columns]

# %%
df1.plot( grid=True, figsize=(30,20))
# Out:
# <AxesSubplot:>

# %%
df1[['Manufacturer','Sales_in_thousands' ]].plot(grid=True, figsize=(20,10))
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html
# Out:
# <AxesSubplot:>

# %%
df1[['Manufacturer','Sales_in_thousands' ]].iloc[1:30].plot.scatter(x="Manufacturer", y="Sales_in_thousands",   grid=True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Sales_in_thousands'>

# %%
df1[['Manufacturer','Model','Sales_in_thousands' ]].iloc[1:40].plot.area(x="Manufacturer", y="Sales_in_thousands", figsize=(10,4),   grid=True, subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Manufacturer'>], dtype=object)

# %%
df1[['Manufacturer','Model','Sales_in_thousands' ]].iloc[1:40].plot.area(x="Model", y="Sales_in_thousands", figsize=(10,4),   grid=True, subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Model'>], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

## Matplotlib Sample Code using 2D arrays via meshgrid
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)
Z = np.sin(R)
fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title('Original Code')
plt.show()
# Out:
# /tmp/ipykernel_67/3998715482.py:14: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
